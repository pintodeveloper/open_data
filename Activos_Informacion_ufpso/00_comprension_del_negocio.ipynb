# %%
Entrenamiento en ciencia de datos pinto 77

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ruta = "Activos_Informacion_UFPS_Ocana.csv"

df = pd.read_csv(ruta, sep=",")

# %%
#1.Conocer los datos
print(df.shape)  # filas y columnas
# Out:
# (66669, 10)

# %%
df.info()   # tipos, nulos y memoria
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 66669 entries, 0 to 66668
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   PROCESO                           66669 non-null  str
#  1   ACTIVO                            66669 non-null  str
#  2   DESCRIPCION                       66386 non-null  str
#  3   DUENO_ DEL_ACTIVO                 66669 non-null  str
#  4   TIPO_DE_ACTIVO                    66669 non-null  str
#  5   IDIOMA                            66669 non-null  str
#  6   MEDIO_DE_CONSERVACION_Y_O_SOPRTE  66669 non-null  str
#  7   FORMATO                           65426 non-null  str
#  8   DISPONIBLE                        66669 non-null  str
#  9   PUBLICADA                         66669 non-null  bool
# dtypes: bool(1), str(9)
# memory usage: 4.6 MB

# %%
display(df.head()) #primeras 5 filas
# Out:
#                          PROCESO ACTIVO  \
# 0              Gestión Académica   Acta
# 1              Gestión Académica   Acta
# 2              Gestión Académica   Acta
# 3  Admisiones Registro y Control   Acta
# 4              Gestión Académica   Acta
#
#                                          DESCRIPCION  \
# 0                               Auditorio Barbatusco
# 1                                    Auditorio CIDER
# 2                                    Auditorio CIDER
# 3  Invitación reunión virtual: meet.google.com/fb...
# 4                                    Auditorio I 202
#
#                           DUENO_ DEL_ACTIVO TIPO_DE_ACTIVO   IDIOMA  \
# 0          DEPARTAMENTO INGENIERÍA MECÁNICA    INFORMACION  Español
# 1  DEPARTAMENTO DE CIENCIAS ADMINISTRATIVAS    INFORMACION  Español
# 2              GRUPO DE INVESTIGACIÓN GIDSE    INFORMACION  Español
# 3          OFICINA DE ADMISIONES Y REGISTRO    INFORMACION  Español
# ...

# %%
display(df.sample(5)) # 5 filas azar
# Out:
#                   PROCESO      ACTIVO  \
# 63137      Gestión Humana  Resolución
# 19586   Gestión Académica      Oficio
# 31361  Secretaría General      Oficio
# 36590   Gestión Académica      Oficio
# 60642   Gestión Académica      Oficio
#
#                                              DESCRIPCION  \
# 63137  RECONOCIMIENTO DE BONIFICACION A NELSON AFANAD...
# 19586  Carta de Presentación - CAROLINA  CASTILLAS VE...
# 31361  Notas registrada carga académica docente José ...
# 36590  Notificación realización practicas de laboratorio
# 60642                     Respuesta oficio O-AC-FAA-0035
#
#                           DUENO_ DEL_ACTIVO TIPO_DE_ACTIVO   IDIOMA  \
# 63137                  DIVISIÓN DE PERSONAL    INFORMACION  Español
# 19586                  OFICINA DE PASANTÍAS    INFORMACION  Español
# 31361                    SECRETARÍA GENERAL    INFORMACION  Español
# 36590  PLAN DE ESTUDIOS INGENIERÍA MECÁNICA    INFORMACION  Español
# ...

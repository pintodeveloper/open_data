# %%
Entrenamiento en ciencia de datos pinto 77

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ruta = "Activos_Informacion_UFPS_Ocana.csv"

df = pd.read_csv(ruta, sep=",")

# %%
print(df.shape)
# Out:
# (66669, 10)
